# %% [markdown]
# # The Greenhouse Gas (GHS) emissions

# %%
# HIDDEN
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Get GHG emission from agricultural land-use

# %%
# HIDDEN
from tools import get_all_files, get_GHG_file_df
from tools.Plot_GHG import get_GHG_plots,plot_GHG_total

# %% [markdown]
# ## Data preparing

# %%
# HIDE CODE
# Get all output files
from PARAMETERS import DATA_ROOT
files = get_all_files(DATA_ROOT)


# Select files based on criteria
print(files['catetory'].unique(),'\n')
# Out:
# ['GHG' 'dvar' 'ammap' 'cost' 'lmmap' 'lumap' 'revenue' 'water'
#  'cross_table' 'lumap_separate_Agricultural Land-use'
#  'lumap_separate_Non-Agricultural Land-use' 'quantity']

# %% [markdown]
# Filter the GHG data

# %%
# HIDDEN
# Get the GHG files
GHG_files = get_GHG_file_df(files)
GHG_files = GHG_files.reset_index(drop=True).sort_values(['year','GHG_sum_t'])
GHG_files['GHG_sum_Mt'] = GHG_files['GHG_sum_t'] / 1e6
GHG_files
# Out:
#      year   year_types catetory                 base_name base_ext  \
# 2    2010  single_year      GHG  Non-Agricultural Landuse     .csv
# 1    2010  single_year      GHG   Agricultural Management     .csv
# 3    2010  single_year      GHG        Transition Penalty     .csv
# 0    2010  single_year      GHG      Agricultural Landuse     .csv
# 5    2011  single_year      GHG   Agricultural Management     .csv
# ..    ...          ...      ...                       ...      ...
# 156  2049  single_year      GHG      Agricultural Landuse     .csv
# 162  2050  single_year      GHG  Non-Agricultural Landuse     .csv
# 161  2050  single_year      GHG   Agricultural Management     .csv
# 163  2050  single_year      GHG        Transition Penalty     .csv
# 160  2050  single_year      GHG      Agricultural Landuse     .csv
#
#                                                   path     GHG_sum_t  \
# 2    /home/jinzhu/docker_data/LUTO_DATA/2023_12_12_... -1.077782e+05
# 1    /home/jinzhu/docker_data/LUTO_DATA/2023_12_12_...  0.000000e+00
# 3    /home/jinzhu/docker_data/LUTO_DATA/2023_12_12_...  0.000000e+00
# 0    /home/jinzhu/docker_data/LUTO_DATA/2023_12_12_...  9.051190e+07
# 5    /home/jinzhu/docker_data/LUTO_DATA/2023_12_12_... -6.962467e+05
# ..                                                 ...           ...
# 156  /home/jinzhu/docker_data/LUTO_DATA/2023_12_12_...  7.678707e+07
# 162  /home/jinzhu/docker_data/LUTO_DATA/2023_12_12_... -3.156916e+08
# 161  /home/jinzhu/docker_data/LUTO_DATA/2023_12_12_... -2.598248e+07
# 163  /home/jinzhu/docker_data/LUTO_DATA/2023_12_12_...  6.538516e+04
# 160  /home/jinzhu/docker_data/LUTO_DATA/2023_12_12_...  7.623306e+07
#
#      GHG_sum_Mt
# 2     -0.107778
# 1      0.000000
# 3      0.000000
# 0     90.511903
# 5     -0.696247
# ..          ...
# 156   76.787068
# 162 -315.691620
# 161  -25.982478
# 163    0.065385
# 160   76.233061
#
# [164 rows x 8 columns]

# %% [markdown]
# Calculate the net emissions

# %%
# HIDDEN
# Calculate the net emissions
Net_emission = GHG_files.groupby('year')['GHG_sum_Mt'].sum(numeric_only = True).reset_index()
Net_emission = Net_emission.rename(columns={'GHG_sum_Mt':'Net_emission'})

Net_emission['Net_emission_cum'] = Net_emission['Net_emission'].cumsum()
Net_emission.head(3)
# Out:
#    year  Net_emission  Net_emission_cum
# 0  2010     90.404125         90.404125
# 1  2011     88.270862        178.674987
# 2  2012     86.541724        265.216711

# %% [markdown]
# ## Total GHG emissions across years

# %%
# HIDDEN
cumsum_plot, individual_plot = plot_GHG_total(GHG_files, Net_emission)

# %%
# HIDE CODE 
cumsum_plot
# Out:
# alt.Chart(...)

# %%
# HIDE CODE 
individual_plot
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ## Agricultural Land use Emissions

# %% [markdown]
# Get the Agricultural land-use data

# %%
# HIDDEN
# Initialize the class
ag_lucc_GHG = get_GHG_plots(GHG_files,'Agricultural Landuse','GHG emissions (Mt CO2e)')

# %% [markdown]
# ### Emissions by Crops/Livestocks

# %%
# HIDE CODE
# get the df and plot
GHG_crop_lvstk_df,GHG_crop_lvstk_plot = ag_lucc_GHG.plot_GHG_crop_lvstk()
GHG_crop_lvstk_plot
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Emissions by differrnt irrigation system

# %%
# HIDE CODE
# get the df and plot
GHG_dry_irr_df,GHG_dry_irr_plot = ag_lucc_GHG.plot_GHG_dry_irr()
GHG_dry_irr_plot
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Emissions by GHG category

# %%
# HIDE CODE
# get the df and plot
GHG_catetory_df,GHG_atetory_plot = ag_lucc_GHG.plot_GHG_category()
GHG_atetory_plot
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Emission by CO2 sources

# %%
# HIDE CODE
# get the df and plot
GHG_sources_df,GHG_sources_plot = ag_lucc_GHG.plot_GHG_sources()
GHG_sources_plot
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Emissions by {land-use}-{irrigation} cmobined

# %%
# HIDE CODE
# get the df and plot
GHG_lu_lm_df,GHG_lu_lm_plot = ag_lucc_GHG.plot_GHG_lu_lm(2050)
GHG_lu_lm_plot
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Emissions by {Land-use}-{GHG source} combined

# %%
# HIDE CODE
# get the df and plot
GHG_lu_source_df,GHG_lu_source_plot = ag_lucc_GHG.plot_GHG_lu_source(2050)
GHG_lu_source_plot
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Non-Agricultural Land-use GHG reductions/sequestrations

# %% [markdown]
# ### Data preparation

# %%
# HIDDEN
# Initialize the class
non_ag_lucc_GHG = get_GHG_plots(GHG_files,'Non-Agricultural Landuse','GHG sequestration (Mt CO2e)')
# Out:
# /home/jinzhu/VIS_LUTO/tools/Plot_GHG.py:224: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   return pd.concat([GHG_CO2,GHG_nonCO2],axis=0).reset_index(drop=True)

# %% [markdown]
# ### Sequestrations in total

# %%
# HIDE CODE
# get the df and plot
GHG_non_ag_crop_lvstk_df,GHG_non_ag_crop_lvstk_plot = non_ag_lucc_GHG.plot_GHG_crop_lvstk()
GHG_non_ag_crop_lvstk_plot
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Sequestrations by irrigation system

# %%
# # HIDE CODE
# # get the df and plot
# GHG_non_ag_dry_irr_df,GHG_non_ag_dry_irr_plot = non_ag_lucc_GHG.plot_GHG_dry_irr()
# GHG_non_ag_dry_irr_plot

# %% [markdown]
# ## Agricultural Management GHG reductions

# %% [markdown]
# ### Data preparation

# %%
# HIDDEN
# Initialize the class
ag_man_GHG = get_GHG_plots(GHG_files,'Agricultural Management','GHG reductions (Mt CO2e)')

# %% [markdown]
# ### Sequestrations by Crops/Livestocks

# %%
# HIDE CODE
# get the df and plot
GHG_ag_man_GHG_crop_lvstk_df,GHG_ag_man_GHG_crop_lvstk_plot = ag_man_GHG.plot_GHG_crop_lvstk()
GHG_ag_man_GHG_crop_lvstk_plot
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Reductions by irrigation system

# %%
# HIDE CODE
# get the df and plot
GHG_ag_man_dry_irr_df,GHG_ag_man_dry_irr_plot = ag_man_GHG.plot_GHG_dry_irr()
GHG_ag_man_dry_irr_plot
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Sequestrations by GHG category

# %%
# HIDE CODE
# get the df and plot
GHG_ag_man_df,GHG_ag_man_plot = ag_man_GHG.plot_GHG_category()
GHG_ag_man_plot
# Out:
# alt.LayerChart(...)
