# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np

from glob import glob
import altair as alt
from tqdm.auto import tqdm

from tools import get_all_files

# %%
# Get the root directory of the data
data_root = '../2023_11_03__17_49_42_hard_mincost_RF30_P1e4_Won_Gon'

# Get all output files
files = get_all_files(data_root)
files['year'] = files['year'].astype(int)

# Define crop-lvstk land uses
LU_crops = ['Apples','Citrus','Cotton','Grapes','Hay','Nuts','Other non-cereal crops',
            'Pears','Plantation fruit','Rice','Stone fruit','Sugar','Summer cereals',
            'Summer legumes','Summer oilseeds','Tropical stone fruit','Vegetables',
            'Winter cereals','Winter legumes','Winter oilseeds']

LU_lvstk = ['Beef - modified land','Beef - natural land','Dairy - modified land',
             'Dairy - natural land','Sheep - modified land','Sheep - natural land']

# %%
# Select files based on criteria
files_selc = files.query('year <= 2050')
print(files_selc['catetory'].unique(),'\n')

files_selc
# Out:
# ['GHG' 'dvar' 'ammap' 'lmmap' 'lumap_separate' 'lumap' 'water'
#  'cross_table' 'quantity']
#       year     catetory                                       base_name  \
# 0     2010          GHG                                   GHG_emissions
# 1     2010          GHG     GHG_emissions_separate_agricultural_landuse
# 2     2010          GHG  GHG_emissions_separate_agricultural_management
# 3     2010          GHG          GHG_emissions_separate_no_ag_reduction
# 4     2010          GHG       GHG_emissions_separate_transition_penalty
# ...    ...          ...                                             ...
# 2482  2050  cross_table                                switches-irrstat
# 2483  2050  cross_table                                  switches-lmmap
# 2484  2050  cross_table                                  switches-lumap
# 2485  2050  cross_table           switches-precision-agriculture-amstat
# 2486  2050        water                             water_demand_vs_use
#
#      base_ext                                               path
# 0        .csv  ../2023_11_03__17_49_42_hard_mincost_RF30_P1e4...
# 1        .csv  ../2023_11_03__17_49_42_hard_mincost_RF30_P1e4...
# 2        .csv  ../2023_11_03__17_49_42_hard_mincost_RF30_P1e4...
# 3        .csv  ../2023_11_03__17_49_42_hard_mincost_RF30_P1e4...
# 4        .csv  ../2023_11_03__17_49_42_hard_mincost_RF30_P1e4...
# ...       ...                                                ...
# 2482     .csv  ../2023_11_03__17_49_42_hard_mincost_RF30_P1e4...
# 2483     .csv  ../2023_11_03__17_49_42_hard_mincost_RF30_P1e4...
# 2484     .csv  ../2023_11_03__17_49_42_hard_mincost_RF30_P1e4...
# 2485     .csv  ../2023_11_03__17_49_42_hard_mincost_RF30_P1e4...
# 2486     .csv  ../2023_11_03__17_49_42_hard_mincost_RF30_P1e4...
#
# [2487 rows x 5 columns]

# %% [markdown]
# ## GHG emissions

# %%
# Get only GHG_seperate files
GHG_files = files_selc.query('catetory == "GHG" and base_name != "GHG_emissions" ').reset_index(drop=True)
GHG_files['GHG_sum_t'] = GHG_files['path'].apply(lambda x: pd.read_csv(x,index_col=0).loc['SUM','SUM'])
GHG_files = GHG_files.replace({'base_name': {'GHG_emissions_separate_agricultural_landuse': 'Agricultural Landuse',
                                             'GHG_emissions_separate_agricultural_management': 'Agricultural Management',
                                             'GHG_emissions_separate_no_ag_reduction': 'Non-Agricultural Landuse',
                                             'GHG_emissions_separate_transition_penalty': 'Transition Penalty'}})

# %%
# Get the GHG files
GHG_files = GHG_files.reset_index(drop=True).sort_values(['year','GHG_sum_t'])
GHG_files['GHG_sum_Mt'] = GHG_files['GHG_sum_t'] / 1e6
GHG_files.head(3)
# Out:
#    year catetory                 base_name base_ext  \
# 0  2010      GHG   Agricultural Management     .csv
# 1  2010      GHG  Non-Agricultural Landuse     .csv
# 2  2010      GHG        Transition Penalty     .csv
#
#                                                 path  GHG_sum_t  GHG_sum_Mt
# 0  ../2023_11_03__17_49_42_hard_mincost_RF30_P1e4...        0.0         0.0
# 1  ../2023_11_03__17_49_42_hard_mincost_RF30_P1e4...        0.0         0.0
# 2  ../2023_11_03__17_49_42_hard_mincost_RF30_P1e4...        0.0         0.0

# %%
# Calculate the net emissions
Net_emission = GHG_files.groupby('year')['GHG_sum_Mt'].sum(numeric_only = True).reset_index()
Net_emission = Net_emission.rename(columns={'GHG_sum_Mt':'Net_emission'})
Net_emission.head(3)
# Out:
#    year  Net_emission
# 0  2010     36.820685
# 1  2011    -70.476159
# 2  2012    -70.124035

# %%
# Convert to wide format for plotting in Flourish
GHG_files_wide = GHG_files.pivot(index='year', columns='base_name', values='GHG_sum_Mt').reset_index()
GHG_files_wide.insert(1, 'Net Emission', GHG_files_wide[['Agricultural Landuse','Agricultural Management','Non-Agricultural Landuse']].sum(axis=1))
GHG_files_wide.to_csv('output/GHG_files_wide.csv', index=False)

# %% [markdown]
# ### 0) Total emissions -- Column chart

# %%
# Create a base chart with the necessary transformations and encodings
base_chart = alt.Chart(GHG_files).transform_calculate(
    GHG_sum_Mt = "datum.GHG_sum_t/1000000"
).encode(
    x=alt.X('year:O',axis=alt.Axis(title="Year", labelAngle=-90)),  # Treat year as an ordinal data type
    tooltip=[alt.Tooltip('base_name', title='GHG Category'),
             alt.Tooltip('GHG_sum_Mt:Q', title='Emissions (Mt CO2e)')]
).properties(
    width=600,
    height=400
)



# Create a column chart with the base chart
column_chart = base_chart.mark_bar().encode(
    color=alt.Color('base_name:N',legend=alt.Legend(
                                            title="GHG Category",
                                            orient='none',
                                            legendX=130, legendY=-40,
                                            direction='horizontal',
                                            titleAnchor='middle')),  
    y=alt.Y('GHG_sum_Mt:Q',title='Emissions (Mt CO2e)'),  # Treat GHA_accumulative as a quantitative field
)

# Create a column chart with the base chart
line_chart = alt.Chart(Net_emission).mark_line(color='black').encode(
    tooltip=[alt.Tooltip('Net_emission:Q',title='Net Quantity (Mt CO2e)')],
    x=alt.X('year:O'),
    y=alt.Y('Net_emission:Q',title='Net Quantity (Mt CO2e)'))


# Combine the layers into a final chart
final_chart = alt.layer(
    column_chart,
    line_chart,
).properties(
    width=800,
    height=450
)


final_chart
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### 1) Agricultural Land use Emissions

# %% [markdown]
# #### 1-1) Emissions by Crops/Lvstk -- Stack column

# %%
# Get GHG emissions from ag lucc
GHG_ag_lucc = GHG_files.query('base_name == "Agricultural Landuse"').reset_index(drop=True)
GHG_ag_lucc.head(3)
# Out:
#    year catetory             base_name base_ext  \
# 0  2010      GHG  Agricultural Landuse     .csv
# 1  2011      GHG  Agricultural Landuse     .csv
# 2  2012      GHG  Agricultural Landuse     .csv
#
#                                                 path     GHG_sum_t  GHG_sum_Mt
# 0  ../2023_11_03__17_49_42_hard_mincost_RF30_P1e4...  3.682068e+07   36.820685
# 1  ../2023_11_03__17_49_42_hard_mincost_RF30_P1e4...  3.887889e+07   38.878895
# 2  ../2023_11_03__17_49_42_hard_mincost_RF30_P1e4...  3.821777e+07   38.217768

# %%
def read_GHG_to_long(in_df,GHG_type):

    # Read GHG emissions of ag lucc
    CSVs = []
    for _,row in tqdm(in_df.iterrows(),total=in_df.shape[0]):
        csv = pd.read_csv(row['path'],index_col=0,header=[0,1,2]).drop('SUM',axis=1)

        csv_crop = csv[[True if i in LU_crops else False for i in  csv.index]]
        csv_crop.index = pd.MultiIndex.from_product(([row['year']], csv_crop.index, ['Crop']))

        csv_lvstk = csv[[True if i in LU_lvstk else False for i in  csv.index]]
        csv_lvstk.index = pd.MultiIndex.from_tuples(tuple(csv_lvstk.index.str.split(' - ')))
        csv_lvstk = csv_lvstk.groupby(level=0).sum()
        csv_lvstk.index = pd.MultiIndex.from_product(([row['year']], csv_lvstk.index, ['Livestock']))

        csv = pd.concat([csv_crop,csv_lvstk],axis=1)
        CSVs.append(csv)

    # Convert the GHG_AG to long format, so that each variable is in one column
    GHG_df = pd.concat(CSVs,axis=0)
    GHG_df = GHG_df.droplevel(0,axis=1)
    
    GHG_df_long = GHG_df.copy()
    GHG_df_long.columns = ["+".join(i) for i in GHG_df_long.columns.tolist()]
    GHG_df_long = GHG_df_long.reset_index()
    GHG_df_long.columns = ['Year','Land use','Land use category'] + GHG_df_long.columns.tolist()[3:]

    GHG_df_long = GHG_df_long.melt(id_vars=['Year','Land use','Land use category'],
                                         value_vars=GHG_df_long.columns.tolist()[3:],
                                         value_name='val_t')


    GHG_df_long[f'{GHG_type} (Mt CO2e)'] = GHG_df_long['val_t'] / 1e6
    GHG_df_long[['Irrigation','Sources']] = GHG_df_long['variable'].str.split('+',expand=True)
    GHG_df_long.drop(['val_t','variable'],axis=1,inplace=True)
    GHG_df_long = GHG_df_long.reindex(columns=['Year','Land use category','Land use',
                                                     'Irrigation','Sources',f'{GHG_type} (Mt CO2e)'])

    return GHG_df_long

# %%
# get the long formated table
GHG_ag_df_long = read_GHG_to_long(GHG_ag_lucc,'GHG emissions')
GHG_ag_df_long.to_csv('output/GHG_ag_df_long.csv',index=False)
GHG_ag_df_long.head(3)
# Out:
#   0%|          | 0/41 [00:00<?, ?it/s]
#    Year Land use category Land use Irrigation          Sources  \
# 0  2010              Crop   Citrus        dry  TCO2E_CHEM_APPL
# 1  2010              Crop   Cotton        dry  TCO2E_CHEM_APPL
# 2  2010              Crop   Grapes        dry  TCO2E_CHEM_APPL
#
#    GHG emissions (Mt CO2e)
# 0                 0.000000
# 1                 0.019594
# 2                 0.000000

# %%
GHG_ag_crop_lvstk_total = GHG_ag_df_long.groupby(['Year','Land use category']).sum().reset_index()
GHG_ag_crop_lvstk_total.head(3)
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_24564\885423915.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   GHG_ag_crop_lvstk_total = GHG_ag_df_long.groupby(['Year','Land use category']).sum().reset_index()
#    Year Land use category  GHG emissions (Mt CO2e)
# 0  2010              Crop                17.735888
# 1  2010         Livestock                19.084797
# 2  2011              Crop                13.035769

# %%
base_chart = alt.Chart(GHG_ag_crop_lvstk_total).encode(
    x=alt.X('Year:O',axis=alt.Axis(title="Year", labelAngle=-90)),  # Treat year as an ordinal data type
    tooltip=[alt.Tooltip('Land use category:O', title='Landuse type'),
             alt.Tooltip('GHG emissions (Mt CO2e):Q', title='Emissions (Mt CO2e)')]
).properties(
    width=600,
    height=400
)

column_chart = base_chart.mark_bar().encode(
    color=alt.Color('Land use category:N',legend=alt.Legend(
                                            title="Landuse type",
                                            orient='none',
                                            legendX=350, legendY=-40,
                                            direction='horizontal',
                                            titleAnchor='middle')),  
    y=alt.Y('GHG emissions (Mt CO2e):Q',title='Emissions (Mt CO2e)'),  # Treat GHA_accumulative as a quantitative field
)

final_chart = alt.layer(
    column_chart,
).properties(
    width=800,
    height=450
)

final_chart
# Out:
# alt.LayerChart(...)

# %% [markdown]
# #### 1-2) Emissions by dry/irr -- Stack columns

# %%
# make the long format table
GHG_ag_lm_total = GHG_ag_df_long.groupby(['Year','Irrigation']).sum(numeric_only=True).reset_index()
GHG_ag_lm_total.head(3)
# Out:
#    Year Irrigation  GHG emissions (Mt CO2e)
# 0  2010        dry                30.126696
# 1  2010        irr                 6.693989
# 2  2011        dry                35.701458

# %%
base_chart = alt.Chart(GHG_ag_lm_total).encode(
    x=alt.X('Year:O',axis=alt.Axis(title="Year", labelAngle=-90)),  # Treat year as an ordinal data type
    tooltip=[alt.Tooltip('Irrigation', title='Irrigation'),
             alt.Tooltip('GHG emissions (Mt CO2e):Q', title='Emissions (Mt CO2e)')]
).properties(
    width=600,
    height=400
)


column_chart = base_chart.mark_bar().encode(
    color=alt.Color('Irrigation:N',legend=alt.Legend(
                                                    title="Irrigation",
                                                    orient='none',
                                                    legendX=350, legendY=-40,
                                                    direction='horizontal',
                                                    titleAnchor='middle')),  
    y=alt.Y('GHG emissions (Mt CO2e):Q',
        title='Emissions (Mt CO2e)')
)



final_chart = alt.layer(
    column_chart,
).properties(
    width=800,
    height=450
)

final_chart
# Out:
# alt.LayerChart(...)

# %% [markdown]
# #### 1-3) Emissions by lu-lm cmobined

# %%
GHG_ag_lu_lm = GHG_ag_df_long.groupby(['Year','Land use category','Land use','Irrigation']).sum(numeric_only=True).reset_index()
GHG_ag_lu_lm.to_csv('output/GHG_ag_lu_lm.csv',index=False)

GHG_ag_lu_lm.head(3)
# Out:
#    Year Land use category Land use Irrigation  GHG emissions (Mt CO2e)
# 0  2010              Crop   Citrus        dry                 0.000000
# 1  2010              Crop   Citrus        irr                 0.481071
# 2  2010              Crop   Cotton        dry                 0.134431

# %%
def plot_GHG_ag_lu_lm(total_df,year):
    df = total_df.query('Year == @year').reset_index(drop=True)
    plot = alt.Chart(df).mark_bar().encode(
        # column="Land use category:O",
        x="GHG emissions (Mt CO2e):Q",
        y="Land use:O",
        color="Irrigation:N",
    ).properties(width=220)

    return plot

# %%
plot_GHG_ag_lu_lm(GHG_ag_lu_lm,2010)
# Out:
# alt.Chart(...)

# %%
plot_GHG_ag_lu_lm(GHG_ag_lu_lm,2050)
# Out:
# alt.Chart(...)

# %% [markdown]
# #### 1-4) Emissions by lu-sources combined

# %%
GHG_ag_df_long.head(3)
# Out:
#    Year Land use category Land use Irrigation          Sources  \
# 0  2010              Crop   Citrus        dry  TCO2E_CHEM_APPL
# 1  2010              Crop   Cotton        dry  TCO2E_CHEM_APPL
# 2  2010              Crop   Grapes        dry  TCO2E_CHEM_APPL
#
#    GHG emissions (Mt CO2e)
# 0                 0.000000
# 1                 0.019594
# 2                 0.000000

# %%
GHG_ag_lu_source = GHG_ag_df_long.groupby(['Year','Land use','Irrigation','Sources']).sum(numeric_only=True).reset_index()

GHG_ag_lu_source.to_csv('output/GHG_ag_lu_source.csv',index=False)

# %%
GHG_ag_lu_source.head(3)
# Out:
#    Year Land use Irrigation          Sources  GHG emissions (Mt CO2e)
# 0  2010     Beef        dry  TCO2E_CHEM_APPL                      0.0
# 1  2010     Beef        dry   TCO2E_CROP_MGT                      0.0
# 2  2010     Beef        dry     TCO2E_CULTIV                      0.0

# %%
GHG_ag_lu_source\
        .query('Year == 2050')\
        .pivot(index=['Irrigation','Land use'],columns=['Sources'],values='GHG emissions (Mt CO2e)')
# Out:
# Sources                            TCO2E_CHEM_APPL  TCO2E_CROP_MGT  \
# Irrigation Land use
# dry        Beef                           0.014446        0.001798
#            Cotton                         0.027411        0.000000
#            Dairy                          0.000000        0.000000
#            Grapes                         0.019614        0.008189
#            Hay                            0.010322        0.000000
#            Nuts                           0.012490        0.003468
#            Other non-cereal crops         0.000000        0.000000
#            Rice                           0.000000        0.000000
#            Sheep                          0.000000        0.000000
#            Sugar                          0.027765        0.000000
#            Summer cereals                 0.017025        0.000000
#            Vegetables                     0.000000        0.000000
#            Winter cereals                 0.775017        0.001446
#            Winter legumes                 0.081668        0.003137
#            Winter oilseeds                0.055076        0.000000
# irr        Beef                           0.023682        0.001477
#            Cotton                         0.000000        0.000000
#            Dairy                          0.018941        0.000000
#            Grapes                         0.000000        0.000000
#            Hay                            0.000000        0.000000
#            Nuts                           0.000000        0.000000
#            Other non-cereal crops         0.010246        0.004560
#            Rice                           0.001461        0.000010
#            Sheep                          0.000000        0.000000
#            Sugar                          0.002264        0.000858
#            Summer cereals                 0.000000        0.000000
#            Vegetables                     0.009452        0.001665
#            Winter cereals                 0.000000        0.000000
#            Winter legumes                 0.000000        0.000000
#            Winter oilseeds                0.000000        0.000000
#
# Sources                            TCO2E_CULTIV  TCO2E_DUNG_URINE  TCO2E_ELEC  \
# Irrigation Land use
# dry        Beef                        0.015247          0.261877    0.000000
#            Cotton                      0.012605          0.000000    0.000000
#            Dairy                       0.000000          0.032855    0.053002
#            Grapes                      0.008404          0.000000    0.000000
#            Hay                         0.180320          0.000000    0.000000
#            Nuts                        0.008545          0.000000    0.000000
#            Other non-cereal crops      0.000000          0.000000    0.000000
#            Rice                        0.000000          0.000000    0.000000
#            Sheep                       0.000000          1.418362    0.000000
#            Sugar                       0.102195          0.000000    0.000000
#            Summer cereals              0.031385          0.000000    0.000000
#            Vegetables                  0.000000          0.000000    0.000000
#            Winter cereals              0.166494          0.000000    0.000000
#            Winter legumes              0.010837          0.000000    0.000000
#            Winter oilseeds             0.026887          0.000000    0.000000
# irr        Beef                        0.054433          0.031684    0.000000
#            Cotton                      0.000000          0.000000    0.000000
#            Dairy                       0.042104          0.013194    0.022916
#            Grapes                      0.000000          0.000000    0.000000
#            Hay                         0.000000          0.000000    0.000000
#            Nuts                        0.000000          0.000000    0.000000
#            Other non-cereal crops      0.018969          0.000178    0.000415
#            Rice                        0.004866          0.000000    0.000000
#            Sheep                       0.000000          0.000000    0.000000
#            Sugar                       0.002573          0.000000    0.000000
#            Summer cereals              0.000000          0.000000    0.000000
#            Vegetables                  0.009354          0.001103    0.000000
#            Winter cereals              0.000000          0.000000    0.000000
#            Winter legumes              0.000000          0.000000    0.000000
#            Winter oilseeds             0.000000          0.000000    0.000000
#
# Sources                            TCO2E_ENTERIC  TCO2E_FERT_PROD  \
# Irrigation Land use
# dry        Beef                         3.810327         0.122678
#            Cotton                       0.000000         0.037908
#            Dairy                        0.302004         0.000000
#            Grapes                       0.000000         0.042987
#            Hay                          0.000000         0.384469
#            Nuts                         0.000000         0.046540
#            Other non-cereal crops       0.000000         0.000000
#            Rice                         0.000000         0.000000
#            Sheep                       14.052137         0.000000
#            Sugar                        0.000000         0.206864
#            Summer cereals               0.000000         0.049725
#            Vegetables                   0.000000         0.000000
#            Winter cereals               0.000000         1.981701
#            Winter legumes               0.000000         0.143897
#            Winter oilseeds              0.000000         0.356824
# irr        Beef                         0.333733         0.153103
#            Cotton                       0.000000         0.000000
#            Dairy                        0.121018         0.143501
#            Grapes                       0.000000         0.000000
#            Hay                          0.000000         0.000000
#            Nuts                         0.000000         0.000000
#            Other non-cereal crops       0.002134         0.086506
#            Rice                         0.000000         0.030815
#            Sheep                        0.000000         0.000000
#            Sugar                        0.000000         0.000148
#            Summer cereals               0.000000         0.000000
#            Vegetables                   0.011480         0.144525
#            Winter cereals               0.000000         0.000000
#            Winter legumes               0.000000         0.000000
#            Winter oilseeds              0.000000         0.000000
#
# Sources                            TCO2E_FODDER  TCO2E_FUEL  TCO2E_HARVEST  \
# Irrigation Land use
# dry        Beef                        0.068506    0.260990       0.000879
#            Cotton                      0.000000    0.000000       0.054100
#            Dairy                       0.040191    0.041511       0.000000
#            Grapes                      0.000000    0.000000       0.001260
#            Hay                         0.000000    0.000000       0.000000
#            Nuts                        0.000000    0.000000       0.004080
#            Other non-cereal crops      0.000000    0.000000       0.000000
#            Rice                        0.000000    0.000000       0.000000
#            Sheep                       0.253224    2.831160       0.000000
#            Sugar                       0.000000    0.000000       0.004612
#            Summer cereals              0.000000    0.000000       0.008192
#            Vegetables                  0.000000    0.000000       0.000000
#            Winter cereals              0.000000    0.000000       0.203832
#            Winter legumes              0.000000    0.000000       0.010598
#            Winter oilseeds             0.000000    0.000000       0.022207
# irr        Beef                        0.004395    0.074108       0.006040
#            Cotton                      0.000000    0.000000       0.000000
#            Dairy                       0.016825    0.009890       0.005251
#            Grapes                      0.000000    0.000000       0.000000
#            Hay                         0.000000    0.000000       0.000000
#            Nuts                        0.000000    0.000000       0.000000
#            Other non-cereal crops      0.000336    0.001322       0.002885
#            Rice                        0.000000    0.000000       0.000785
#            Sheep                       0.000000    0.000000       0.000000
#            Sugar                       0.000000    0.000000       0.003381
#            Summer cereals              0.000000    0.000000       0.000000
#            Vegetables                  0.000048    0.001451       0.001146
#            Winter cereals              0.000000    0.000000       0.000000
#            Winter legumes              0.000000    0.000000       0.000000
#            Winter oilseeds             0.000000    0.000000       0.000000
#
# Sources                            TCO2E_IND_LEACH_RUNOFF  TCO2E_IRRIG  \
# Irrigation Land use
# dry        Beef                                  0.135190     0.000000
#            Cotton                                0.000000     0.000000
#            Dairy                                 0.042984     0.000000
#            Grapes                                0.000000     0.000000
#            Hay                                   0.000000     0.000000
#            Nuts                                  0.000000     0.000000
#            Other non-cereal crops                0.000000     0.000000
#            Rice                                  0.000000     0.000000
#            Sheep                                 0.687721     0.000000
#            Sugar                                 0.000000     0.000000
#            Summer cereals                        0.000000     0.000000
#            Vegetables                            0.000000     0.000000
#            Winter cereals                        0.000000     0.000000
#            Winter legumes                        0.000000     0.000000
#            Winter oilseeds                       0.000000     0.000000
# irr        Beef                                  0.030050     0.034126
#            Cotton                                0.000000     0.000000
#            Dairy                                 0.017389     0.037636
#            Grapes                                0.000000     0.000000
#            Hay                                   0.000000     0.000000
#            Nuts                                  0.000000     0.000000
#            Other non-cereal crops                0.000231     0.005621
#            Rice                                  0.000000     0.014178
#            Sheep                                 0.000000     0.000000
#            Sugar                                 0.000000     0.000918
#            Summer cereals                        0.000000     0.000000
#            Vegetables                            0.000968     0.006034
#            Winter cereals                        0.000000     0.000000
#            Winter legumes                        0.000000     0.000000
#            Winter oilseeds                       0.000000     0.000000
#
# Sources                            TCO2E_MANURE_MGT  TCO2E_PEST_PROD  \
# Irrigation Land use
# dry        Beef                            0.002129         0.014990
#            Cotton                          0.000000         0.053954
#            Dairy                           0.024423         0.000000
#            Grapes                          0.000000         0.032266
#            Hay                             0.000000         0.134691
#            Nuts                            0.000000         0.017869
#            Other non-cereal crops          0.000000         0.000000
#            Rice                            0.000000         0.000000
#            Sheep                           0.005657         0.000000
#            Sugar                           0.000000         0.128987
#            Summer cereals                  0.000000         0.075127
#            Vegetables                      0.000000         0.000000
#            Winter cereals                  0.000000         1.290315
#            Winter legumes                  0.000000         0.150007
#            Winter oilseeds                 0.000000         0.088013
# irr        Beef                            0.000056         0.043550
#            Cotton                          0.000000         0.000000
#            Dairy                           0.009780         0.035061
#            Grapes                          0.000000         0.000000
#            Hay                             0.000000         0.000000
#            Nuts                            0.000000         0.000000
#            Other non-cereal crops          0.000275         0.018880
#            Rice                            0.000000         0.000904
#            Sheep                           0.000000         0.000000
#            Sugar                           0.000000         0.002368
#            Summer cereals                  0.000000         0.000000
#            Vegetables                      0.000002         0.007600
#            Winter cereals                  0.000000         0.000000
#            Winter legumes                  0.000000         0.000000
#            Winter oilseeds                 0.000000         0.000000
#
# Sources                            TCO2E_SEED  TCO2E_SOIL  TCO2E_SOWING
# Irrigation Land use
# dry        Beef                      0.437704    0.053879      0.001642
#            Cotton                    0.000000    0.047440      0.006011
#            Dairy                     0.027282    0.000000      0.000000
#            Grapes                    0.000000    0.056368      0.000000
#            Hay                       0.000000    0.000000      0.010322
#            Nuts                      0.000000    0.049754      0.000608
#            Other non-cereal crops    0.000000    0.000000      0.000000
#            Rice                      0.000000    0.000000      0.000000
#            Sheep                     0.984300    0.000000      0.000000
#            Sugar                     0.000000    0.623415      0.024405
#            Summer cereals            0.000000    0.011600      0.013590
#            Vegetables                0.000000    0.000000      0.000000
#            Winter cereals            0.000000    0.474296      0.443426
#            Winter legumes            0.000000    0.036678      0.050509
#            Winter oilseeds           0.000000    0.031478      0.027696
# irr        Beef                      0.001035    0.310766      0.012751
#            Cotton                    0.000000    0.000000      0.000000
#            Dairy                     0.021522    0.300411      0.013265
#            Grapes                    0.000000    0.000000      0.000000
#            Hay                       0.000000    0.000000      0.000000
#            Nuts                      0.000000    0.000000      0.000000
#            Other non-cereal crops    0.000012    0.077678      0.003767
#            Rice                      0.000000    0.070164      0.001046
#            Sheep                     0.000000    0.000000      0.000000
#            Sugar                     0.000000    0.000031      0.000000
#            Summer cereals            0.000000    0.000000      0.000000
#            Vegetables                0.000016    0.120788      0.001978
#            Winter cereals            0.000000    0.000000      0.000000
#            Winter legumes            0.000000    0.000000      0.000000
#            Winter oilseeds           0.000000    0.000000      0.000000

# %%
def plot_GHG_ag_lu_source(total_df,year):
    df = total_df.query(f'Year == {year}')
    plot = alt.Chart(df).mark_circle().encode(
        alt.X('Land use:O'),
        alt.Y('Sources:O'),
        alt.Color('Irrigation:O'),
        alt.Size('GHG emissions (Mt CO2e):Q'),
    )
    return plot

# %%
plot_GHG_ag_lu_source(GHG_ag_lu_source,2010)
# Out:
# alt.Chart(...)

# %%
plot_GHG_ag_lu_source(GHG_ag_lu_source,2050)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### 2) AG_management

# %%
GHG_ag_man = GHG_files.query('base_name == "Agricultural Management"').reset_index(drop=True)

# %%
# get the long formated table
GHG_am_df_long = read_GHG_to_long(GHG_ag_man,'GHG sequestration')
GHG_am_df_long.to_csv('output/GHG_am_df_long.csv',index=False)
GHG_am_df_long.head(3)
# Out:
#   0%|          | 0/41 [00:00<?, ?it/s]
#    Year Land use category Land use Irrigation                        Sources  \
# 0  2010              Crop   Citrus        dry  TCO2E_Asparagopsis taxiformis
# 1  2010              Crop   Cotton        dry  TCO2E_Asparagopsis taxiformis
# 2  2010              Crop   Grapes        dry  TCO2E_Asparagopsis taxiformis
#
#    GHG sequestration (Mt CO2e)
# 0                          0.0
# 1                          0.0
# 2                          0.0

# %% [markdown]
# #### 2-1) Agricultural Management - stack columns

# %%
GHG_am_crop_lvstk_total = GHG_am_df_long.groupby(['Year','Land use category']).sum(numeric_only = True).reset_index()
GHG_am_crop_lvstk_total.head(3)
# Out:
#    Year Land use category  GHG sequestration (Mt CO2e)
# 0  2010              Crop                          0.0
# 1  2010         Livestock                          0.0
# 2  2011              Crop                          0.0

# %%
base_chart = alt.Chart(GHG_am_crop_lvstk_total).encode(
    x=alt.X('Year:O',axis=alt.Axis(title="Year", labelAngle=-90)),  # Treat year as an ordinal data type
    tooltip=[alt.Tooltip('Land use category:O', title='Landuse type'),
             alt.Tooltip('GHG sequestration (Mt CO2e):Q', title='GHG sequestration (Mt CO2e)')]
).properties(
    width=600,
    height=400
)

column_chart = base_chart.mark_bar().encode(
    color=alt.Color('Land use category:N',legend=alt.Legend(
                                            title="Landuse type",
                                            orient='none',
                                            legendX=350, legendY=-40,
                                            direction='horizontal',
                                            titleAnchor='middle')),  
    y=alt.Y('GHG sequestration (Mt CO2e):Q',
            title='GHG sequestration (Mt CO2e)',
            scale=alt.Scale(reverse=True)),  # Treat GHA_accumulative as a quantitative field
)

final_chart = alt.layer(
    column_chart,
).properties(
    width=800,
    height=450
)

final_chart
# Out:
# alt.LayerChart(...)

# %% [markdown]
# #### 2-2) Seqestrations by dry/irr - stack column

# %%
# make the long format table
GHG_am_lm_total = GHG_am_df_long.groupby(['Year','Irrigation']).sum(numeric_only=True).reset_index()
GHG_am_lm_total.head(3)
# Out:
#    Year Irrigation  GHG sequestration (Mt CO2e)
# 0  2010        dry                      0.00000
# 1  2010        irr                      0.00000
# 2  2011        dry                     -0.35231

# %%
base_chart = alt.Chart(GHG_am_lm_total).encode(
    x=alt.X('Year:O',axis=alt.Axis(title="Year", labelAngle=-90)),  # Treat year as an ordinal data type
    tooltip=[alt.Tooltip('Irrigation', title='Irrigation'),
             alt.Tooltip('GHG sequestration (Mt CO2e):Q', title='GHG sequestration (Mt CO2e)')]
).properties(
    width=600,
    height=400
)


column_chart = base_chart.mark_bar().encode(
    color=alt.Color('Irrigation:N',legend=alt.Legend(
                                                    title="Irrigation",
                                                    orient='none',
                                                    legendX=350, legendY=-40,
                                                    direction='horizontal',
                                                    titleAnchor='middle')),  
    y=alt.Y('GHG sequestration (Mt CO2e):Q',
            title='Emissions (Mt CO2e)',
            scale=alt.Scale(reverse=True))
)



final_chart = alt.layer(
    column_chart,
).properties(
    width=800,
    height=450
)



final_chart
# Out:
# alt.LayerChart(...)
