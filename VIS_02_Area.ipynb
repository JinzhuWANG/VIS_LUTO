# %% [markdown]
# # The Area changes

# %%
# HIDDEN
# %load_ext autoreload
# %autoreload 2

# %%
# HIDDEN
import re
from tools import get_all_files
from PARAMETERS import DATA_ROOT
from tools.Plot_AREA import get_AREA_lu, plot_area_lu,\
                            get_AREA_lm, plot_area_lm,\
                            get_AREA_am, plot_area_am_total, plot_area_am_lu

# %%
# HIDDEN
# Get all output files
files = get_all_files(DATA_ROOT)

# %%
# HIDDEN
# Select files based on criteria
files_selc = files.query('year <= 2050')
print(files_selc['catetory'].unique(),'\n')

files_selc
# Out:
# ['GHG' 'dvar' 'ammap' 'lmmap' 'lumap' 'water' 'cross_table' 'quantity']
#       year     catetory                                       base_name  \
# 0     2010          GHG                                   GHG_emissions
# 1     2010          GHG     GHG_emissions_separate_agricultural_landuse
# 2     2010          GHG  GHG_emissions_separate_agricultural_management
# 3     2010          GHG          GHG_emissions_separate_no_ag_reduction
# 4     2010          GHG       GHG_emissions_separate_transition_penalty
# ...    ...          ...                                             ...
# 1293  2050  cross_table                                switches-irrstat
# 1294  2050  cross_table                                  switches-lmmap
# 1295  2050  cross_table                                  switches-lumap
# 1296  2050  cross_table           switches-precision-agriculture-amstat
# 1297  2050        water                             water_demand_vs_use
#
#      base_ext                                               path
# 0        .csv  ../2023_11_20__01_27_24_hard_mincost_RF5_P1e8_...
# 1        .csv  ../2023_11_20__01_27_24_hard_mincost_RF5_P1e8_...
# 2        .csv  ../2023_11_20__01_27_24_hard_mincost_RF5_P1e8_...
# 3        .csv  ../2023_11_20__01_27_24_hard_mincost_RF5_P1e8_...
# 4        .csv  ../2023_11_20__01_27_24_hard_mincost_RF5_P1e8_...
# ...       ...                                                ...
# 1293     .csv  ../2023_11_20__01_27_24_hard_mincost_RF5_P1e8_...
# 1294     .csv  ../2023_11_20__01_27_24_hard_mincost_RF5_P1e8_...
# 1295     .csv  ../2023_11_20__01_27_24_hard_mincost_RF5_P1e8_...
# 1296     .csv  ../2023_11_20__01_27_24_hard_mincost_RF5_P1e8_...
# 1297     .csv  ../2023_11_20__01_27_24_hard_mincost_RF5_P1e8_...
#
# [1298 rows x 5 columns]

# %% [markdown]
# ## 1 Get the total area (km2) change

# %%
# HIDDEN
Area_df = files_selc.query('catetory == "cross_table"').reset_index(drop=True)
Area_df
# Out:
#      year     catetory                                base_name base_ext  \
# 0    2011  cross_table  crosstab-asparagopsis-taxiformis-amstat     .csv
# 1    2011  cross_table       crosstab-ecological-grazing-amstat     .csv
# 2    2011  cross_table                         crosstab-irrstat     .csv
# 3    2011  cross_table                           crosstab-lmmap     .csv
# 4    2011  cross_table                           crosstab-lumap     .csv
# ..    ...          ...                                      ...      ...
# 475  2050  cross_table       switches-ecological-grazing-amstat     .csv
# 476  2050  cross_table                         switches-irrstat     .csv
# 477  2050  cross_table                           switches-lmmap     .csv
# 478  2050  cross_table                           switches-lumap     .csv
# 479  2050  cross_table    switches-precision-agriculture-amstat     .csv
#
#                                                   path
# 0    ../2023_11_20__01_27_24_hard_mincost_RF5_P1e8_...
# 1    ../2023_11_20__01_27_24_hard_mincost_RF5_P1e8_...
# 2    ../2023_11_20__01_27_24_hard_mincost_RF5_P1e8_...
# 3    ../2023_11_20__01_27_24_hard_mincost_RF5_P1e8_...
# 4    ../2023_11_20__01_27_24_hard_mincost_RF5_P1e8_...
# ..                                                 ...
# 475  ../2023_11_20__01_27_24_hard_mincost_RF5_P1e8_...
# 476  ../2023_11_20__01_27_24_hard_mincost_RF5_P1e8_...
# 477  ../2023_11_20__01_27_24_hard_mincost_RF5_P1e8_...
# 478  ../2023_11_20__01_27_24_hard_mincost_RF5_P1e8_...
# 479  ../2023_11_20__01_27_24_hard_mincost_RF5_P1e8_...
#
# [480 rows x 5 columns]

# %%
# HIDDEN
Area_df['base_name'].unique()
# Out:
# array(['crosstab-asparagopsis-taxiformis-amstat',
#        'crosstab-ecological-grazing-amstat', 'crosstab-irrstat',
#        'crosstab-lmmap', 'crosstab-lumap',
#        'crosstab-precision-agriculture-amstat',
#        'switches-asparagopsis-taxiformis-amstat',
#        'switches-ecological-grazing-amstat', 'switches-irrstat',
#        'switches-lmmap', 'switches-lumap',
#        'switches-precision-agriculture-amstat'], dtype=object)

# %% [markdown]
# ### Plot land use areas between years

# %%
# HIDDEN
crosstab_lu = Area_df.query('base_name == "crosstab-lumap"').reset_index(drop=True)
crosstab_lu.head(3)
# Out:
#    year     catetory       base_name base_ext  \
# 0  2011  cross_table  crosstab-lumap     .csv
# 1  2012  cross_table  crosstab-lumap     .csv
# 2  2013  cross_table  crosstab-lumap     .csv
#
#                                                 path
# 0  ../2023_11_20__01_27_24_hard_mincost_RF5_P1e8_...
# 1  ../2023_11_20__01_27_24_hard_mincost_RF5_P1e8_...
# 2  ../2023_11_20__01_27_24_hard_mincost_RF5_P1e8_...

# %%
# HIDE CODE
lu_area = get_AREA_lu(crosstab_lu)
plot_area_lu(lu_area)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Plot the total area (km2) for lm

# %%
# HIDDEN
crosstab_lm = Area_df.query('base_name == "crosstab-lmmap"').reset_index(drop=True)
crosstab_lm.head(3)
# Out:
#    year     catetory       base_name base_ext  \
# 0  2011  cross_table  crosstab-lmmap     .csv
# 1  2012  cross_table  crosstab-lmmap     .csv
# 2  2013  cross_table  crosstab-lmmap     .csv
#
#                                                 path
# 0  ../2023_11_20__01_27_24_hard_mincost_RF5_P1e8_...
# 1  ../2023_11_20__01_27_24_hard_mincost_RF5_P1e8_...
# 2  ../2023_11_20__01_27_24_hard_mincost_RF5_P1e8_...

# %%
# HIDE CODE
lm_area = get_AREA_lm(crosstab_lm)
plot_area_lm(lm_area)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### 1-3) Plot the area change of agricultural managements

# %%
# HIDDEN
switches_am = Area_df.query('base_name.str.contains(r"switches.*amstat.*", regex=True)').reset_index(drop=True)
switches_am.head(3)
# Out:
#    year     catetory                                base_name base_ext  \
# 0  2011  cross_table  switches-asparagopsis-taxiformis-amstat     .csv
# 1  2011  cross_table       switches-ecological-grazing-amstat     .csv
# 2  2011  cross_table    switches-precision-agriculture-amstat     .csv
#
#                                                 path
# 0  ../2023_11_20__01_27_24_hard_mincost_RF5_P1e8_...
# 1  ../2023_11_20__01_27_24_hard_mincost_RF5_P1e8_...
# 2  ../2023_11_20__01_27_24_hard_mincost_RF5_P1e8_...

# %%
# HIDE CODE
am_area_km2 = get_AREA_am(switches_am)
am_area_km2[['Land use','Agricultural management']] = am_area_km2['Land use']\
                                                     .apply(lambda x: re.findall(r'(.*) \((.*)\)',x)[0]).tolist()

plot_area_am_lu(am_area_km2)
# Out:
# alt.Chart(...)

# %%
# HIDE CODE
am_area_km2_total = am_area_km2.groupby(['Year','Agricultural management']).sum(numeric_only=True).reset_index()
plot_area_am_total(am_area_km2_total)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### 1-4) Plot crosstab changes

# %%
# HIDDEN
from PARAMETERS import AG_LANDUSE, NON_AG_LANDUSE
import pandas as pd
import numpy as np

total_area = lu_area
all_lucc = AG_LANDUSE + NON_AG_LANDUSE
crosstab_lu = crosstab_lu.sort_values(by=['year']).reset_index(drop=True)

year_start = 2010
year_end = 2050

# %%
# HIDDEN
dfs = []
for _,row in crosstab_lu.iterrows():
    year = row['year']

    # get the area dataframe and remove the last row and column
    df = pd.read_csv(row['path'],index_col=0).iloc[:-1,:-1]
    # reindex teh dataframe to avoid missing land use classes
    df = df.reindex(all_lucc, axis=0).reindex(all_lucc, axis=1)
    # move the index to a column
    df.index = pd.MultiIndex.from_product([[year],df.index])
    # add the year column
    df.insert(0,'year',year)

    dfs.append(df)

# get the transition matrix for all years
crosstab_lu_all = pd.concat(dfs)
crosstab_lu_all = crosstab_lu_all\
            .groupby(level=1,axis=0)\
            .sum(numeric_only=True)\
            .drop(columns=['year'])

crosstab_lu_all = crosstab_lu_all.reindex(columns=crosstab_lu_all.index)

# fill the diagonal with the last year's values
crosstab_lu_all_val = crosstab_lu_all.values
np.fill_diagonal(crosstab_lu_all_val, np.diag(df.drop(columns=['year'])))
# np.fill_diagonal(crosstab_lu_all_val, 0)

crosstab_lu_all[:] = crosstab_lu_all_val

crosstab_lu_all = crosstab_lu_all.reset_index(names='Land-use from')

# convert the dataframe to long format
crosstab_lu_all = crosstab_lu_all\
    .melt(id_vars='Land-use from', 
          value_vars=crosstab_lu_all.columns[1:], 
          var_name='Land-use to', 
          value_name='Area (km2)')\
    .reset_index(names='from')

# %%
# HIDE CODE
# plot the transition matrix using altair
import altair as alt

alt.Chart(crosstab_lu_all.reset_index()).mark_rect().encode(
    x='Land-use from:N',
    y='Land-use to:N',
    color='Area (km2):Q',
    tooltip=['Land-use from','Land-use to','Area (km2)']
).properties(
    width=400,
    height=400
).interactive()
# Out:
# alt.Chart(...)
