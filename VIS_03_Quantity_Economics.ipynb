# %%
# HIDDEN
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# HIDDEN
import re
from tools import get_all_files
from PARAMETERS import DATA_ROOT

from tools.Plot_Quantity import plot_quantity, get_quantity_df

# %%
# HIDDEN
# Get all output files
files = get_all_files(DATA_ROOT)

# %%
# HIDDEN
# Select files based on criteria
files_selc = files.query('year <= 2050')
print(files_selc['catetory'].unique(),'\n')

files_selc
# Out:
# ['GHG' 'cost' 'revenue' 'water' 'cross_table' 'quantity' 'dvar' 'ammap'
#  'lmmap' 'lumap']
#       year      year_types     catetory  \
# 0     2010  begin_end_year          GHG
# 1     2010  begin_end_year          GHG
# 2     2010  begin_end_year          GHG
# 3     2010  begin_end_year          GHG
# 4     2010  begin_end_year          GHG
# ...    ...             ...          ...
# 1528  2050     single_year  cross_table
# 1529  2050     single_year  cross_table
# 1530  2050     single_year  cross_table
# 1531  2050     single_year  cross_table
# 1532  2050     single_year        water
#
#                                               base_name base_ext  \
# 0                    GHG_emissions_2023_12_11__16_10_48     .csv
# 1     GHG_emissions_separate_agricultural_landuse_20...     .csv
# 2     GHG_emissions_separate_agricultural_management...     .csv
# 3     GHG_emissions_separate_no_ag_reduction_2023_12...     .csv
# 4     GHG_emissions_separate_transition_penalty_2023...     .csv
# ...                                                 ...      ...
# 1528                                   switches-irrstat     .csv
# 1529                                     switches-lmmap     .csv
# 1530                                     switches-lumap     .csv
# 1531              switches-precision-agriculture-amstat     .csv
# 1532                                water_demand_vs_use     .csv
#
#                                                    path
# 0     ../docker_data/LUTO_DATA/CWC15_2023_11_23__07_...
# 1     ../docker_data/LUTO_DATA/CWC15_2023_11_23__07_...
# 2     ../docker_data/LUTO_DATA/CWC15_2023_11_23__07_...
# 3     ../docker_data/LUTO_DATA/CWC15_2023_11_23__07_...
# 4     ../docker_data/LUTO_DATA/CWC15_2023_11_23__07_...
# ...                                                 ...
# 1528  ../docker_data/LUTO_DATA/CWC15_2023_11_23__07_...
# 1529  ../docker_data/LUTO_DATA/CWC15_2023_11_23__07_...
# 1530  ../docker_data/LUTO_DATA/CWC15_2023_11_23__07_...
# 1531  ../docker_data/LUTO_DATA/CWC15_2023_11_23__07_...
# 1532  ../docker_data/LUTO_DATA/CWC15_2023_11_23__07_...
#
# [1533 rows x 6 columns]

# %% [markdown]
# # Get the total quantity change

# %%
# HIDDEN
Quantity_df = files_selc.query('catetory == "quantity" and base_name == "quantity_comparison" and year_types == "single_year"').reset_index(drop=True)
Quantity_df.head(3)
# Out:
#    year   year_types  catetory            base_name base_ext  \
# 0  2011  single_year  quantity  quantity_comparison     .csv
# 1  2012  single_year  quantity  quantity_comparison     .csv
# 2  2013  single_year  quantity  quantity_comparison     .csv
#
#                                                 path
# 0  ../docker_data/LUTO_DATA/CWC15_2023_11_23__07_...
# 1  ../docker_data/LUTO_DATA/CWC15_2023_11_23__07_...
# 2  ../docker_data/LUTO_DATA/CWC15_2023_11_23__07_...

# %%
# HIDE CODE
quantity_df = get_quantity_df(Quantity_df)
plot_quantity(quantity_df)
# Out:
# alt.Chart(...)

# %%
quantity_df
# Out:
#                  Commodity  Prod_targ_year (tonnes, KL)  year  \
# 0                   Apples                 2.623581e+05  2011
# 1                Beef lexp                 3.079528e+05  2011
# 2                Beef meat                 2.655481e+06  2011
# 3                   Citrus                 5.547902e+05  2011
# 4                   Cotton                 1.022520e+06  2011
# ...                    ...                          ...   ...
# 1035  Tropical stone fruit                 1.726046e+05  2050
# 1036            Vegetables                 5.753996e+06  2050
# 1037        Winter cereals                 7.481547e+07  2050
# 1038        Winter legumes                 4.613383e+06  2050
# 1039       Winter oilseeds                 4.667871e+06  2050
#
#       Prod_targ_year (tonnes, ML)
# 0                      262.358142
# 1                      307.952791
# 2                     2655.481101
# 3                      554.790168
# 4                     1022.519826
# ...                           ...
# 1035                   172.604569
# 1036                  5753.996480
# 1037                 74815.465998
# 1038                  4613.383476
# 1039                  4667.871260
#
# [1040 rows x 4 columns]
